# %% [markdown]
# # Ejercicio 161
#
# Seleccionar todas las columnas de un `DataFrame`, excepto una en particular.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df = df.loc[:, df.columns != 'Y']

# %%
df
# Out:
#    X  Z
# 0  1  2
# 1  2  2
# 2  3  5
# 3  4  7
# 4  1  1

# %% [markdown]
# # Ejercicio 162
#
# Remover las primeras `n` filas (registros) de un objeto `DataFrame` usando `iloc`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
df.iloc[3:]
# Out:
#    nombre  puntaje  intentos califico
# d  Germán      NaN         3       No
# e  Edward      8.0         2       No
# f    Alex     19.0         3       Sí
# g   Julio     13.5         1       Sí
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %%
df.iloc[-3:] # empieza en el 3 pero borra hasta los siguientes 3, al revés que antes
# Out:
#    nombre  puntaje  intentos califico
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 163
#
# Remover las últimas `n` filas (registros) de un objeto `DataFrame` usando `iloc`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
n = 5

df.iloc[:-n]
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No

# %% [markdown]
# # Ejercicio 164
#
# Usar la función `plot` para graficar el contenido de un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
# %matplotlib inline 
# tambien funciona sin

df.dropna().plot(kind='line', y='puntaje', color='red') # dropna() Remove missing values
# Out:
# <Axes: >

# %% [markdown]
# # Ejercicio 165
#
# Crear un gráfico de barras a partir de un objeto `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
# %matplotlib inline

df.groupby('califico')['califico'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='califico'>

# %% [markdown]
# # Ejercicio 166
#
# Graficar múltiples curvas con los datos de un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos = {'nombre': ['Yuli', 'Juliana', 'Sofía', 'Rosa', 'Adriana'],
         'gatos': [2, 3, 2, 1, 1],
         'perros': [2, 1, 3, 2, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#     nombre  gatos  perros
# 0     Yuli      2       2
# 1  Juliana      3       1
# 2    Sofía      2       3
# 3     Rosa      1       2
# 4  Adriana      1       1

# %%
# %matplotlib inline

df.plot(x='nombre')
plt.grid()

# %% [markdown]
# # Ejercicio 167
#
# Guardar un `DataFrame` en formato de serialización pickle de Python.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df.to_pickle('datos.pkl')

# %% [markdown]
# # Ejercicio 168
#
# Leer los datos de un `DataFrame` desde un archivo serializado en pickle de Python.
#
# ## Solución:

# %%
import pandas as pd

# %%
df = pd.read_pickle('datos.pkl')

# %%
df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %% [markdown]
# # Ejercicio 169
#
# Generar la representación en cadena de caracteres de un `DataFrame` con `to_string`.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df.to_string()
# Out:
# '   X  Y  Z\n0  1  5  2\n1  2  2  2\n2  3  3  5\n3  4  2  7\n4  1  0  1'

# %%
print(df.to_string())
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %% [markdown]
# # Ejercicio 170
#
# Obtener la representación de diccionario de un objeto `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df.to_dict()
# Out:
# {'X': {0: 1, 1: 2, 2: 3, 3: 4, 4: 1},
#  'Y': {0: 5, 1: 2, 2: 3, 3: 2, 4: 0},
#  'Z': {0: 2, 1: 2, 2: 5, 3: 7, 4: 1}}

# %% [markdown]
# # Ejercicio 171
#
# Crear una tabla HTML a partir de un objeto `DataFrame` con `to_html`.
#
# ## Solución

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nombre</th>
#       <th>puntaje</th>
#       <th>intentos</th>
#       <th>califico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Oliva</td>
#       <td>11.5</td>
#       <td>1</td>
#       <td>Sí</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>Daniela</td>
#       <td>8.0</td>
#       <td>3</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Juan</td>
#       <td>15.5</td>
#       <td>2</td>
#       <td>Sí</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>Germán</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>Edward</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>Alex</td>
#       <td>19.0</td>
#       <td>3</td>
#       <td>Sí</td>
#     </tr>
#     <tr>
#       <th>g</th>
#       <td>Julio</td>
#       <td>13.5</td>
#       <td>1</td>
#       <td>Sí</td>
#     </tr>
#     <tr>
#       <th>h</th>
#       <td>Edgar</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>Angie</td>
#       <td>8.0</td>
#       <td>2</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>j</th>
#       <td>Irlesa</td>
#       <td>18.0</td>
#       <td>1</td>
#       <td>Sí</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Ejercicio 172
#
# Generar la representación JSON de un objeto `DataFrame` con `to_json`.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df.to_json()
# Out:
# '{"X":{"0":1,"1":2,"2":3,"3":4,"4":1},"Y":{"0":5,"1":2,"2":3,"3":2,"4":0},"Z":{"0":2,"1":2,"2":5,"3":7,"4":1}}'

# %%
import json

# %%
objeto = json.loads(df.to_json())

# %%
type(objeto)
# Out:
# dict

# %%
objeto['X']
# Out:
# {'0': 1, '1': 2, '2': 3, '3': 4, '4': 1}

# %%
objeto['Y']
# Out:
# {'0': 5, '1': 2, '2': 3, '3': 2, '4': 0}

# %%
len(objeto)
# Out:
# 3

# %% [markdown]
# # Ejercicio 173
#
# Guardar los datos de un `DataFrame` en una base de datos SQLite.
#
# ## Solución:

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
engine = c('sqlite://', echo=False)

df.to_sql('datos', con=engine)
# Out:
# 5

# %%
engine.execute('SELECT * FROM datos').fetchall() # execute deprecated

"""
with engine.begin() as conn: 
        result = conn.exec_driver_sql('SELECT * FROM datos')
result
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 engine.execute('SELECT * FROM datos').fetchall() # execute deprecated
#       3 """
#       4 with engine.begin() as conn:
#       5         result = conn.exec_driver_sql('SELECT * FROM datos')
#       6 result
#       7 """
#
# AttributeError: 'Engine' object has no attribute 'execute'

# %% [markdown]
# ## Ejemplo de SQLite

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

df.to_sql("mi_df", conn)

for row in cursor.execute('SELECT * FROM mi_df;'):
    print(row)

conn.close()
# Out:
# (0, 1, 5, 2)
# (1, 2, 2, 2)
# (2, 3, 3, 5)
# (3, 4, 2, 7)
# (4, 1, 0, 1)

# %% [markdown]
# # Ejercicio 174
#
# Guardar los Datos de un `DataFrame` en una Base de Datos MySQL.
#
# ## Solución:

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
cadena_conexion = 'mysql+pymysql://root@localhost:3306/datosbd'
conexion = create_engine(cadena_conexion)

# %%
df.to_sql(name='datos', con=conexion)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\Python\Python312\Lib\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File ~\Python\Python312\Lib\socket.py:865, in create_connection(address, timeout, source_address, all_errors)
#     864 if not all_errors:
# --> 865     raise exceptions[0]
#     866 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~\Python\Python312\Lib\socket.py:850, in create_connection(address, timeout, source_address, all_errors)
#     849     sock.bind(source_address)
# --> 850 sock.connect(sa)
#     851 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\Python\Python312\Lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     360 else:
# --> 361     self.connect()
#
# File ~\Python\Python312\Lib\site-packages\pymysql\connections.py:716, in Connection.connect(self, sock)
#     715         print(exc.traceback)
# --> 716     raise exc
#     718 # If e is neither DatabaseError or IOError, It's a bug.
#     719 # But raising AssertionError hides original error.
#     720 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.to_sql(name='datos', con=conexion)
#
# File ~\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\Python\Python312\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~\Python\Python312\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File ~\Python\Python312\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File ~\Python\Python312\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3278, in Engine.connect(self)
#    3255 def connect(self) -> Connection:
#    3256     """Return a new :class:`_engine.Connection` object.
#    3257
#    3258     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3275
#    3276     """
# -> 3278     return self._connection_cls(self)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:2442, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2440 elif should_wrap:
#    2441     assert sqlalchemy_exception is not None
# -> 2442     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2443 else:
#    2444     assert exc_info[1] is not None
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3280 def raw_connection(self) -> PoolProxiedConnection:
#    3281     """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283     The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301     """
# -> 3302     return self.pool.connect()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\Python\Python312\Lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\Python\Python312\Lib\site-packages\pymysql\connections.py:716, in Connection.connect(self, sock)
#     714     if DEBUG:
#     715         print(exc.traceback)
# --> 716     raise exc
#     718 # If e is neither DatabaseError or IOError, It's a bug.
#     719 # But raising AssertionError hides original error.
#     720 # So just reraise it.
#     721 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# # Ejercicio 175
#
# Crear un `DataFrame` a partir de una consulta SQL.
#
# ## Solución:

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
import sqlite3

conn = sqlite3.connect("C:\\Users\\amerino.practicas\\Downloads\\mibasededatos.sqlite")
cursor = conn.cursor()

df.to_sql("datos", conn)

"""
for row in cursor.execute('SELECT * FROM mi_df;'):
    print(row)

conn.close()
"""
# Out:
# "\nfor row in cursor.execute('SELECT * FROM mi_df;'):\n    print(row)\n\nconn.close()\n"

# %%
"""
cadena_conexion = 'mysql+pymysql://root@localhost:3306/datosbd'
conexion = create_engine(cadena_conexion)
"""
# Out:
# "\ncadena_conexion = 'mysql+pymysql://root@localhost:3306/datosbd'\nconexion = create_engine(cadena_conexion)\n"

# %%
sql = 'SELECT * FROM datos'

df = pd.read_sql_query(sql, con=conn)
conn.close()

# %%
df
# Out:
#    index  X  Y  Z
# 0      0  1  5  2
# 1      1  2  2  2
# 2      2  3  3  5
# 3      3  4  2  7
# 4      4  1  0  1

# %%
df.drop(columns=['index'], inplace=True)


df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %% [markdown]
# # Ejercicio 176
#
# Crear un `DataFrame` con una consulta SQL (con restricción) usando MySQL.
#
# ## Solución::

# %%
import sqlite3
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
"""
cadena_conexion = 'mysql+pymysql://root@localhost:3306/datosbd'
conexion = create_engine(cadena_conexion)
"""

conn = sqlite3.connect("C:\\Users\\amerino.practicas\\Downloads\\mibasededatos.sqlite")
cursor = conn.cursor()

# %%
"""
sql = 'SELECT X, Y FROM datos WHERE X <= 2'
df = pd.read_sql_query(sql, con=conexion)
"""

sql = 'SELECT * FROM datos'

df = pd.read_sql_query(sql, con=conn)

# %%
df
# Out:
#    index  X  Y  Z
# 0      0  1  5  2
# 1      1  2  2  2
# 2      2  3  3  5
# 3      3  4  2  7
# 4      4  1  0  1

# %% [markdown]
# # Ejercicio 177
#
# Copiar al portapapeles del sistema operativo el contenido de un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd

# %%
datos = {'X': [1, 2, 3, 4, 1], 'Y': [5, 2, 3, 2, 0], 'Z': [2, 2, 5, 7, 1]}

df = pd.DataFrame(data=datos)

df
# Out:
#    X  Y  Z
# 0  1  5  2
# 1  2  2  2
# 2  3  3  5
# 3  4  2  7
# 4  1  0  1

# %%
df.to_clipboard()

# %%
	X	Y	Z
0	1	5	2
1	2	2	2
2	3	3	5
3	4	2	7
4	1	0	1

# %% [markdown]
# # Ejercicio 178
#
# Pegar en un documento de **Microsoft Word** el contenido de un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
df.to_clipboard(excel=False)

# %% [markdown]
# # Ejercicio 179
#
# Leer un archivo CSV con la función `read_csv` para crear un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  1987-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104      Bruce     Ernst    BERNST  590.423.4568  1987-06-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  1987-09-27
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  1987-09-28
# 104        204    Hermann      Baer     HBAER  515.123.8888  1987-09-29
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206    William     Gietz    WGIETZ  515.123.8181  1987-10-01
#
#          job_id  salary  commission_pct  manager_id  department_id
# 0       AD_PRES   24000             NaN         NaN           90.0
# 1         AD_VP   17000             NaN       100.0           90.0
# 2         AD_VP   17000             NaN       100.0           90.0
# 3       IT_PROG    9000             NaN       102.0           60.0
# 4       IT_PROG    6000             NaN       103.0           60.0
# ..          ...     ...             ...         ...            ...
# 102      MK_REP    6000             NaN       201.0           20.0
# 103      HR_REP    6500             NaN       101.0           40.0
# 104      PR_REP   10000             NaN       101.0           70.0
# 105      AC_MGR   12000             NaN       101.0          110.0
# 106  AC_ACCOUNT    8300             NaN       205.0          110.0
#
# [107 rows x 11 columns]

# %%
df.size
# Out:
# 1177

# %%
df.columns
# Out:
# Index(['employ_id', 'first_name', 'last_name', 'email', 'phone_number',
#        'hire_date', 'job_id', 'salary', 'commission_pct', 'manager_id',
#        'department_id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employ_id       107 non-null    int64
#  1   first_name      107 non-null    object
#  2   last_name       107 non-null    object
#  3   email           107 non-null    object
#  4   phone_number    107 non-null    object
#  5   hire_date       107 non-null    object
#  6   job_id          107 non-null    object
#  7   salary          107 non-null    int64
#  8   commission_pct  35 non-null     float64
#  9   manager_id      106 non-null    float64
#  10  department_id   106 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %%
df.describe().round(3)
# Out:
#        employ_id     salary  commission_pct  manager_id  department_id
# count    107.000    107.000          35.000     106.000        106.000
# mean     153.000   6461.682           0.223     124.764         63.208
# std       31.032   3909.366           0.085      20.315         20.910
# min      100.000   2100.000           0.100     100.000         10.000
# 25%      126.500   3100.000           0.150     108.000         50.000
# 50%      153.000   6200.000           0.200     122.000         50.000
# 75%      179.500   8900.000           0.300     145.000         80.000
# max      206.000  24000.000           0.400     205.000        110.000

# %% [markdown]
# # Ejercicio 180
#
# Crear un `DataFrame` a partir del contenido del portapapeles del sistema usando `read_clipboard`.
#
# ## Solución:

# %%
import pandas as pd

# %% [markdown]
# `_	X	Y	Z
# 0	1	5	2
# 1	2	2	2
# 2	3	3	5
# 3	4	2	7
# 4	1	0	1
# `

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#    _  X  Y  Z
# 0  0  1  5  2
# 1  1  2  2  2
# 2  2  3  3  5
# 3  3  4  2  7
# 4  4  1  0  1

# %% [markdown]
# # Ejercicio 181
#
# Crear un `DataFrame` a partir de un archivo de **Microsoft Excel**.
#
# ## Solución:

# %%
import pandas as pd

# %%
df = pd.read_excel('produccion.xlsx')

# %%
df
# Out:
#   Unnamed: 0     0
# 0      Enero  1000
# 1    Febrero  1100
# 2      Marzo   900
# 3      Abril   850
# 4       Mayo   950

# %%
df.describe().round(2)
# Out:
#              0
# count     5.00
# mean    960.00
# std      96.18
# min     850.00
# 25%     900.00
# 50%     950.00
# 75%    1000.00
# max    1100.00

# %% [markdown]
# # Ejercicio 182
#
# Leer un archivo JSON con `read_json` para crear un objeto `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'productos.json'

df = pd.read_excel('produccion.xlsx')
df.to_json('productos.json')

df = pd.read_json(nombre_archivo)

# %%
df
# Out:
#   Unnamed: 0     0
# 0      Enero  1000
# 1    Febrero  1100
# 2      Marzo   900
# 3      Abril   850
# 4       Mayo   950

# %% [markdown]
# # Ejercicio 183
#
# Generar el esquema tabular de un `DataFrame` con `build_table_schema`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

estudiantes = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data=estudiantes, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
pd.io.json.build_table_schema(df)
# Out:
# {'fields': [{'name': 'index', 'type': 'string'},
#   {'name': 'nombre', 'type': 'string'},
#   {'name': 'puntaje', 'type': 'number'},
#   {'name': 'intentos', 'type': 'integer'},
#   {'name': 'califico', 'type': 'string'}],
#  'primaryKey': ['index'],
#  'pandas_version': '1.4.0'}

# %% [markdown]
# # Ejercicio 184
#
# Leer un archivo HTML para crear un objeto `DataFrame` usando `read_html`.
#
# ## Solución:

# %%
from bs4 import BeautifulSoup as bs

import pandas as pd

# %%
import os.path
os.path.isfile("tabla.html")
# Out:
# True

# %%
nombre_archivo = 'tabla.html'

df = pd.read_html(nombre_archivo)[0]
df
# Out:
#                        País           Capital Moneda
# 0           Reino de España            Madrid   Euro
# 1  Estados Unidos Mexicanos  Ciudad de México   Peso
# 2       República Argentina      Buenos Aires   Peso

# %%
nombre_archivo = 'tabla.html'

#df = bs.read_html_table(nombre_archivo)[0]
with open(nombre_archivo) as f:
    soup = bs(f, 'html.parser')
    print(soup.title)
table = soup.find('table')
print(soup.title)
print(soup(itemprop="Capital"))

table = pd.read_html(nombre_archivo)[0]
# Out:
# None
# None
# []

# %%
df
# Out:
#                        País           Capital Moneda
# 0           Reino de España            Madrid   Euro
# 1  Estados Unidos Mexicanos  Ciudad de México   Peso
# 2       República Argentina      Buenos Aires   Peso

# %% [markdown]
# # Ejercicio 185
#
# Usar la función `not_null` para identificar valores nulos en un `DataFrame`.
#
# ## Solución:

# %%
import pandas as pd
import numpy as np

# %%
datos = {'X': [1, 2, np.nan, 4, None], 'Y': [5, 2, 3, None, 0], 'Z': [2, 2, 5, 7, np.nan]}

df = pd.DataFrame(data=datos)

df
# Out:
#      X    Y    Z
# 0  1.0  5.0  2.0
# 1  2.0  2.0  2.0
# 2  NaN  3.0  5.0
# 3  4.0  NaN  7.0
# 4  NaN  0.0  NaN

# %%
pd.isnull(df)
# Out:
#        X      Y      Z
# 0  False  False  False
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False
# 4   True  False   True

# %%
df.isnull()
# Out:
#        X      Y      Z
# 0  False  False  False
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False
# 4   True  False   True

# %% [markdown]
# # Ejercicio 186
#
# Obtener los elementos distintos de una columna de un `DataFrame` con `unique`.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'departments.csv'

df = pd.read_csv(nombre_archivo)

# %%
df
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# 13            140    Control And Credit         NaN         1700
# 14            150  Shareholder Services         NaN         1700
# 15            160              Benefits         NaN         1700
# 16            170         Manufacturing         NaN         1700
# 17            180          Construction         NaN         1700
# 18            190           Contracting         NaN         1700
# 19            200            Operations         NaN         1700
# 20            210            IT Support         NaN         1700
# 21            220                   NOC         NaN         1700
# 22            230           IT Helpdesk         NaN         1700
# 23            240      Government Sales         NaN         1700
# 24            250          Retail Sales         NaN         1700
# 25            260            Recruiting         NaN         1700
# 26            270               Payroll         NaN         1700

# %%
df.location_id.unique()
# Out:
# array([1700, 1800, 2400, 1500, 1400, 2700, 2500])

# %% [markdown]
# # Ejercicio 187
#
# Encontrar registros de un `DataFrame` que cumplan una condición respecto a una columna.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado = df[df.salary <= 3000]
resultado.head()
# Out:
#     employ_id first_name    last_name     email  phone_number   hire_date  \
# 16        116     Shelli        Baida    SBAIDA  515.127.4563  1987-07-03
# 17        117      Sigal       Tobias   STOBIAS  515.127.4564  1987-07-04
# 18        118        Guy       Himuro   GHIMURO  515.127.4565  1987-07-05
# 19        119      Karen   Colmenares  KCOLMENA  515.127.4566  1987-07-06
# 26        126      Irene  Mikkilineni  IMIKKILI  650.124.1224  1987-07-13
#
#       job_id  salary  commission_pct  manager_id  department_id
# 16  PU_CLERK    2900             NaN       114.0           30.0
# 17  PU_CLERK    2800             NaN       114.0           30.0
# 18  PU_CLERK    2600             NaN       114.0           30.0
# 19  PU_CLERK    2500             NaN       114.0           30.0
# 26  ST_CLERK    2700             NaN       120.0           50.0

# %%
len(resultado)
# Out:
# 26

# %%
len(df)
# Out:
# 107

# %%
for index, registro in resultado.iterrows():
    print('{:<10}{:>30}{:>20}'.format(registro['first_name'], registro['last_name'], registro['salary']))
# Out:
# Shelli                             Baida                2900
# Sigal                             Tobias                2800
# Guy                               Himuro                2600
# Karen                         Colmenares                2500
# Irene                        Mikkilineni                2700
# James                             Landry                2400
# Steven                            Markle                2200
# Mozhe                           Atkinson                2800
# James                             Marlow                2500
# TJ                                 Olson                2100
# Michael                           Rogers                2900
# Ki                                   Gee                2400
# Hazel                         Philtanker                2200
# John                                 Seo                2700
# Joshua                             Patel                2500
# Randall                            Matos                2600
# Peter                             Vargas                2500
# Martha                          Sullivan                2500
# Girard                             Geoni                2800
# Anthony                           Cabrio                3000
# Timothy                            Gates                2900
# Randall                          Perkins                2500
# Vance                              Jones                2800
# Kevin                             Feeney                3000
# Donald                          OConnell                2600
# Douglas                            Grant                2600

# %% [markdown]
# # Ejercicio 188
#
# Obtener los registros donde el nombre de un empleado empiece con *J*.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado = df[df['first_name'].str[:1] == 'J']

# %%
resultado
# Out:
#      employ_id   first_name   last_name     email        phone_number  \
# 10         110         John        Chen     JCHEN        515.124.4269
# 12         112  Jose Manuel       Urman   JMURMAN        515.124.4469
# 25         125        Julia       Nayer    JNAYER        650.124.1214
# 27         127        James      Landry   JLANDRY        650.124.1334
# 31         131        James      Marlow   JAMRLOW        650.124.7234
# 33         133        Jason      Mallin   JMALLIN        650.127.1934
# 39         139         John         Seo      JSEO        650.121.2019
# 40         140       Joshua       Patel    JPATEL        650.121.1834
# 45         145         John     Russell   JRUSSEL  011.44.1344.429268
# 56         156      Janette        King     JKING  011.44.1345.429268
# 76         176     Jonathon      Taylor   JTAYLOR  011.44.1644.429265
# 77         177         Jack  Livingston  JLIVINGS  011.44.1644.429264
# 81         181         Jean      Fleaur   JFLEAUR        650.507.9877
# 86         186        Julia   Dellinger  JDELLING        650.509.3876
# 89         189     Jennifer       Dilly    JDILLY        650.505.2876
# 100        200     Jennifer      Whalen   JWHALEN        515.123.4444
#
#       hire_date      job_id  salary  commission_pct  manager_id  department_id
# 10   1987-06-27  FI_ACCOUNT    8200             NaN       108.0          100.0
# 12   1987-06-29  FI_ACCOUNT    7800             NaN       108.0          100.0
# 25   1987-07-12    ST_CLERK    3200             NaN       120.0           50.0
# 27   1987-07-14    ST_CLERK    2400             NaN       120.0           50.0
# 31   1987-07-18    ST_CLERK    2500             NaN       121.0           50.0
# 33   1987-07-20    ST_CLERK    3300             NaN       122.0           50.0
# 39   1987-07-26    ST_CLERK    2700             NaN       123.0           50.0
# 40   1987-07-27    ST_CLERK    2500             NaN       123.0           50.0
# 45   1987-08-01      SA_MAN   14000            0.40       100.0           80.0
# 56   1987-08-12      SA_REP   10000            0.35       146.0           80.0
# 76   1987-09-01      SA_REP    8600            0.20       149.0           80.0
# 77   1987-09-02      SA_REP    8400            0.20       149.0           80.0
# 81   1987-09-06    SH_CLERK    3100             NaN       120.0           50.0
# 86   1987-09-11    SH_CLERK    3400             NaN       121.0           50.0
# 89   1987-09-14    SH_CLERK    3600             NaN       122.0           50.0
# 100  1987-09-25     AD_ASST    4400             NaN       101.0           10.0

# %%
len(df)
# Out:
# 107

# %%
len(resultado)
# Out:
# 16

# %% [markdown]
# ## Ejercicio 189
#
# Obtener aquellos empleados donde su apellido no contenga la letra *h*.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado = df[df['last_name'].str.lower().str.find('h') == -1]

# %%
resultado.head(3)
# Out:
#    employ_id first_name last_name    email  phone_number   hire_date   job_id  \
# 0        100     Steven      King    SKING  515.123.4567  1987-06-17  AD_PRES
# 4        104      Bruce     Ernst   BERNST  590.423.4568  1987-06-21  IT_PROG
# 5        105      David    Austin  DAUSTIN  590.423.4569  1987-06-22  IT_PROG
#
#    salary  commission_pct  manager_id  department_id
# 0   24000             NaN         NaN           90.0
# 4    6000             NaN       103.0           60.0
# 5    4800             NaN       103.0           60.0

# %% [markdown]
# # Ejercicio 190
#
# Ordenar en modo descendente los empleados a partir de su ID de departamento.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado = df.sort_values('department_id', ascending=False)

# %%
resultado.head(4)
# Out:
#      employ_id   first_name last_name     email  phone_number   hire_date  \
# 105        205      Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206      William     Gietz    WGIETZ  515.123.8181  1987-10-01
# 13         113         Luis      Popp     LPOPP  515.124.4567  1987-06-30
# 12         112  Jose Manuel     Urman   JMURMAN  515.124.4469  1987-06-29
#
#          job_id  salary  commission_pct  manager_id  department_id
# 105      AC_MGR   12000             NaN       101.0          110.0
# 106  AC_ACCOUNT    8300             NaN       205.0          110.0
# 13   FI_ACCOUNT    6900             NaN       108.0          100.0
# 12   FI_ACCOUNT    7800             NaN       108.0          100.0

# %%
resultado = df.sort_values(by=['department_id', 'employ_id'], ascending=False)

# %%
resultado
# Out:
#      employ_id   first_name  last_name     email        phone_number  \
# 105        205      Shelley    Higgins  SHIGGINS        515.123.8080
# 106        206      William      Gietz    WGIETZ        515.123.8181
# 13         113         Luis       Popp     LPOPP        515.124.4567
# 12         112  Jose Manuel      Urman   JMURMAN        515.124.4469
# 11         111       Ismael    Sciarra  ISCIARRA        515.124.4369
# ..         ...          ...        ...       ...                 ...
# 18         118          Guy     Himuro   GHIMURO        515.127.4565
# 101        201      Michael  Hartstein  MHARTSTE        515.123.5555
# 102        202          Pat        Fay      PFAY        603.123.6666
# 100        200     Jennifer     Whalen   JWHALEN        515.123.4444
# 78         178    Kimberely      Grant    KGRANT  011.44.1644.429263
#
#       hire_date      job_id  salary  commission_pct  manager_id  department_id
# 105  1987-09-30      AC_MGR   12000             NaN       101.0          110.0
# 106  1987-10-01  AC_ACCOUNT    8300             NaN       205.0          110.0
# 13   1987-06-30  FI_ACCOUNT    6900             NaN       108.0          100.0
# 12   1987-06-29  FI_ACCOUNT    7800             NaN       108.0          100.0
# 11   1987-06-28  FI_ACCOUNT    7700             NaN       108.0          100.0
# ..          ...         ...     ...             ...         ...            ...
# 18   1987-07-05    PU_CLERK    2600             NaN       114.0           30.0
# 101  1987-09-26      MK_MAN   13000             NaN       100.0           20.0
# 102  1987-09-27      MK_REP    6000             NaN       201.0           20.0
# 100  1987-09-25     AD_ASST    4400             NaN       101.0           10.0
# 78   1987-09-03      SA_REP    7000            0.15       149.0            NaN
#
# [107 rows x 11 columns]

# %% [markdown]
# # Ejercicio 191
#
# Obtener el empleado que es gerente de la empresa.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
resultado = df[df['manager_id'].isnull()]

# %%
resultado
# Out:
#    employ_id first_name last_name  email  phone_number   hire_date   job_id  \
# 0        100     Steven      King  SKING  515.123.4567  1987-06-17  AD_PRES
#
#    salary  commission_pct  manager_id  department_id
# 0   24000             NaN         NaN           90.0

# %% [markdown]
# # Ejercicio 192
#
# Encontrar todos los empleados que están a cargo de un jefe.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado = df[df['manager_id'].notnull()]

# %%
resultado
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104      Bruce     Ernst    BERNST  590.423.4568  1987-06-21
# 5          105      David    Austin   DAUSTIN  590.423.4569  1987-06-22
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  1987-09-27
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  1987-09-28
# 104        204    Hermann      Baer     HBAER  515.123.8888  1987-09-29
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206    William     Gietz    WGIETZ  515.123.8181  1987-10-01
#
#          job_id  salary  commission_pct  manager_id  department_id
# 1         AD_VP   17000             NaN       100.0           90.0
# 2         AD_VP   17000             NaN       100.0           90.0
# 3       IT_PROG    9000             NaN       102.0           60.0
# 4       IT_PROG    6000             NaN       103.0           60.0
# 5       IT_PROG    4800             NaN       103.0           60.0
# ..          ...     ...             ...         ...            ...
# 102      MK_REP    6000             NaN       201.0           20.0
# 103      HR_REP    6500             NaN       101.0           40.0
# 104      PR_REP   10000             NaN       101.0           70.0
# 105      AC_MGR   12000             NaN       101.0          110.0
# 106  AC_ACCOUNT    8300             NaN       205.0          110.0
#
# [106 rows x 11 columns]

# %%
resultado2 = df[df['manager_id'] == 100]
resultado2.head(4)
# Out:
#     employ_id first_name last_name     email  phone_number   hire_date  \
# 1         101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2         102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 14        114        Den  Raphaely  DRAPHEAL  515.127.4561  1987-07-01
# 20        120    Matthew     Weiss    MWEISS  650.123.1234  1987-07-07
#
#     job_id  salary  commission_pct  manager_id  department_id
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 14  PU_MAN   11000             NaN       100.0           30.0
# 20  ST_MAN    8000             NaN       100.0           50.0

# %%
len(df)
# Out:
# 107

# %%
len(resultado2)
# Out:
# 14

# %% [markdown]
# # Ejercicio 193
#
# Determinar si una ubicación no se le ha asignado un estado/departamento.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'locations.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    location_id           street_address postal_code                 city  \
# 0         1000     1297 Via Cola di Rie         989                 Roma
# 1         1100  93091 Calle della Testa       10934               Venice
# 2         1200         2017 Shinjuku-ku        1689                Tokyo
# 3         1300          9450 Kamiya-cho        6823            Hiroshima
# 4         1400      2014 Jabberwocky Rd       26192            Southlake
# 5         1500      2011 Interiors Blvd       99236  South San Francisco
# 6         1600           2007 Zagora St       50090      South Brunswick
#
#      state_province country_id
# 0               NaN         IT
# 1               NaN         IT
# 2  Tokyo Prefecture         JP
# 3               NaN         JP
# 4             Texas         US
# 5        California         US
# 6        New Jersey         US

# %%
df['state_province_available'] = df.state_province.notnull()

# %%
df.head(30)
# Out:
#     location_id                            street_address postal_code  \
# 0          1000                      1297 Via Cola di Rie         989
# 1          1100                   93091 Calle della Testa       10934
# 2          1200                          2017 Shinjuku-ku        1689
# 3          1300                           9450 Kamiya-cho        6823
# 4          1400                       2014 Jabberwocky Rd       26192
# 5          1500                       2011 Interiors Blvd       99236
# 6          1600                            2007 Zagora St       50090
# 7          1700                           2004 Charade Rd       98199
# 8          1800                           147 Spadina Ave     M5V 2L7
# 9          1900                           6092 Boxwood St     YSW 9T2
# 10         2000                       40-5-12 Laogianggen      190518
# 11         2100                        1298 Vileparle (E)      490231
# 12         2200                     12-98 Victoria Street        2901
# 13         2300                        198 Clementi North      540198
# 14         2400                            8204 Arthur St         NaN
# 15         2500  Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 16         2600                         9702 Chester Road  9629850293
# 17         2700                     Schwanthalerstr. 7031       80925
# 18         2800                      Rua Frei Caneca 1360   01307-002
# 19         2900                   20 Rue des Corps-Saints        1730
# 20         3000                         Murtenstrasse 921        3095
# 21         3100                 Pieter Breughelstraat 837      3029SK
# 22         3200                     Mariano Escobedo 9991       11932
#
#                    city     state_province country_id  \
# 0                  Roma                NaN         IT
# 1                Venice                NaN         IT
# 2                 Tokyo   Tokyo Prefecture         JP
# 3             Hiroshima                NaN         JP
# 4             Southlake              Texas         US
# 5   South San Francisco         California         US
# 6       South Brunswick         New Jersey         US
# 7               Seattle         Washington         US
# 8               Toronto            Ontario         CA
# 9            Whitehorse              Yukon         CA
# 10              Beijing                NaN         CN
# 11               Bombay        Maharashtra         IN
# 12               Sydney    New South Wales         AU
# 13            Singapore                NaN         SG
# 14               London                NaN         UK
# 15               Oxford             Oxford         UK
# 16            Stretford         Manchester         UK
# 17               Munich            Bavaria         DE
# 18            Sao Paulo          Sao Paulo         BR
# 19               Geneva             Geneve         CH
# 20                 Bern                 BE         CH
# 21              Utrecht            Utrecht         NL
# 22          Mexico City  Distrito Federal,         MX
#
#     state_province_available
# 0                      False
# 1                      False
# 2                       True
# 3                      False
# 4                       True
# 5                       True
# 6                       True
# 7                       True
# 8                       True
# 9                       True
# 10                     False
# 11                      True
# 12                      True
# 13                     False
# 14                     False
# 15                      True
# 16                      True
# 17                      True
# 18                      True
# 19                      True
# 20                      True
# 21                      True
# 22                      True

# %%
# también se puede con df.state_province_available, sin corchetes
sinasignar = sum(1 for i in df['state_province_available'] if i == False)

print(sinasignar)
# Out:
# 6

# %% [markdown]
# # Ejercicio 194
#
# Consultar la cantidad de datos faltantes (nulos) por columna del dataset de ubicaciones.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'locations.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   País     3 non-null      object
#  1   Capital  3 non-null      object
#  2   Moneda   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
df.head(7)
# Out:
#    location_id           street_address postal_code                 city  \
# 0         1000     1297 Via Cola di Rie         989                 Roma
# 1         1100  93091 Calle della Testa       10934               Venice
# 2         1200         2017 Shinjuku-ku        1689                Tokyo
# 3         1300          9450 Kamiya-cho        6823            Hiroshima
# 4         1400      2014 Jabberwocky Rd       26192            Southlake
# 5         1500      2011 Interiors Blvd       99236  South San Francisco
# 6         1600           2007 Zagora St       50090      South Brunswick
#
#      state_province country_id
# 0               NaN         IT
# 1               NaN         IT
# 2  Tokyo Prefecture         JP
# 3               NaN         JP
# 4             Texas         US
# 5        California         US
# 6        New Jersey         US

# %%
df.isna()
# Out:
#     location_id  street_address  postal_code   city  state_province  \
# 0         False           False        False  False            True
# 1         False           False        False  False            True
# 2         False           False        False  False           False
# 3         False           False        False  False            True
# 4         False           False        False  False           False
# 5         False           False        False  False           False
# 6         False           False        False  False           False
# 7         False           False        False  False           False
# 8         False           False        False  False           False
# 9         False           False        False  False           False
# 10        False           False        False  False            True
# 11        False           False        False  False           False
# 12        False           False        False  False           False
# 13        False           False        False  False            True
# 14        False           False         True  False            True
# 15        False           False        False  False           False
# 16        False           False        False  False           False
# 17        False           False        False  False           False
# 18        False           False        False  False           False
# 19        False           False        False  False           False
# 20        False           False        False  False           False
# 21        False           False        False  False           False
# 22        False           False        False  False           False
#
#     country_id
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False

# %%
df.isna().sum()
# Out:
# location_id       0
# street_address    0
# postal_code       1
# city              0
# state_province    6
# country_id        0
# dtype: int64

# %% [markdown]
# # Ejercicio 195
#
# Encontrar los empleados cuyo nombre termina en la letra a.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[df['first_name'].str[-1] == 'a']

# %%
resultado
# Out:
#     employ_id first_name  last_name     email        phone_number   hire_date  \
# 1         101      Neena    Kochhar  NKOCHHAR        515.123.4568  1987-06-18
# 7         107      Diana    Lorentz  DLORENTZ        590.423.5567  1987-06-24
# 23        123     Shanta    Vollman  SVOLLMAN        650.123.4234  1987-07-10
# 25        125      Julia      Nayer    JNAYER        650.124.1214  1987-07-12
# 29        129      Laura     Bissot   LBISSOT        650.124.5234  1987-07-16
# 40        140     Joshua      Patel    JPATEL        650.121.1834  1987-07-27
# 41        141     Trenna       Rajs     TRAJS        650.121.8009  1987-07-28
# 62        162      Clara    Vishney  CVISHNEY  011.44.1346.129268  1987-08-18
# 64        164     Mattea    Marvins  MMARVINS  011.44.1346.329268  1987-08-20
# 68        168       Lisa       Ozer     LOZER  011.44.1343.929268  1987-08-24
# 73        173    Sundita      Kumar    SKUMAR  011.44.1343.329268  1987-08-29
# 75        175     Alyssa     Hutton   AHUTTON  011.44.1644.429266  1987-08-31
# 82        182     Martha   Sullivan  MSULLIVA        650.507.9878  1987-09-07
# 84        184    Nandita   Sarchand  NSARCHAN        650.509.1876  1987-09-09
# 86        186      Julia  Dellinger  JDELLING        650.509.3876  1987-09-11
# 96        196      Alana      Walsh    AWALSH        650.507.9811  1987-09-21
#
#       job_id  salary  commission_pct  manager_id  department_id
# 1      AD_VP   17000             NaN       100.0           90.0
# 7    IT_PROG    4200             NaN       103.0           60.0
# 23    ST_MAN    6500             NaN       100.0           50.0
# 25  ST_CLERK    3200             NaN       120.0           50.0
# 29  ST_CLERK    3300             NaN       121.0           50.0
# 40  ST_CLERK    2500             NaN       123.0           50.0
# 41  ST_CLERK    3500             NaN       124.0           50.0
# 62    SA_REP   10500            0.25       147.0           80.0
# 64    SA_REP    7200            0.10       147.0           80.0
# 68    SA_REP   11500            0.25       148.0           80.0
# 73    SA_REP    6100            0.10       148.0           80.0
# 75    SA_REP    8800            0.25       149.0           80.0
# 82  SH_CLERK    2500             NaN       120.0           50.0
# 84  SH_CLERK    4200             NaN       121.0           50.0
# 86  SH_CLERK    3400             NaN       121.0           50.0
# 96  SH_CLERK    3100             NaN       124.0           50.0

# %%
len(resultado)
# Out:
# 16

# %%
resultado.shape[0]
# Out:
# 16

# %% [markdown]
# # Ejercicio 196
#
# Obtener empleados cuyo nombre empiece ya sea por _a_, _l_ o _r_. Ordenar por ID de departamento.
#
# ## Solución.

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[df['first_name'].str[-1].isin(['a', 'l', 'r'])]

resultado.head(10)
# Out:
#     employ_id   first_name last_name     email  phone_number   hire_date  \
# 1         101        Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 3         103    Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 7         107        Diana   Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 9         109       Daniel    Faviet   DFAVIET  515.124.4169  1987-06-26
# 11        111       Ismael   Sciarra  ISCIARRA  515.124.4369  1987-06-28
# 12        112  Jose Manuel     Urman   JMURMAN  515.124.4469  1987-06-29
# 15        115    Alexander      Khoo     AKHOO  515.127.4562  1987-07-02
# 17        117        Sigal    Tobias   STOBIAS  515.127.4564  1987-07-04
# 23        123       Shanta   Vollman  SVOLLMAN  650.123.4234  1987-07-10
# 25        125        Julia     Nayer    JNAYER  650.124.1214  1987-07-12
#
#         job_id  salary  commission_pct  manager_id  department_id
# 1        AD_VP   17000             NaN       100.0           90.0
# 3      IT_PROG    9000             NaN       102.0           60.0
# 7      IT_PROG    4200             NaN       103.0           60.0
# 9   FI_ACCOUNT    9000             NaN       108.0          100.0
# 11  FI_ACCOUNT    7700             NaN       108.0          100.0
# 12  FI_ACCOUNT    7800             NaN       108.0          100.0
# 15    PU_CLERK    3100             NaN       114.0           30.0
# 17    PU_CLERK    2800             NaN       114.0           30.0
# 23      ST_MAN    6500             NaN       100.0           50.0
# 25    ST_CLERK    3200             NaN       120.0           50.0

# %%
resultado = resultado.sort_values('department_id', ascending=False)

resultado.head(10)
# Out:
#     employ_id   first_name last_name     email        phone_number  \
# 11        111       Ismael   Sciarra  ISCIARRA        515.124.4369
# 9         109       Daniel    Faviet   DFAVIET        515.124.4169
# 12        112  Jose Manuel     Urman   JMURMAN        515.124.4469
# 1         101        Neena   Kochhar  NKOCHHAR        515.123.4568
# 52        152        Peter      Hall     PHALL  011.44.1344.478968
# 68        168         Lisa      Ozer     LOZER  011.44.1343.929268
# 75        175       Alyssa    Hutton   AHUTTON  011.44.1644.429266
# 53        153  Christopher     Olsen    COLSEN  011.44.1344.498718
# 55        155       Oliver   Tuvault  OTUVAULT  011.44.1344.486508
# 50        150        Peter    Tucker   PTUCKER  011.44.1344.129268
#
#      hire_date      job_id  salary  commission_pct  manager_id  department_id
# 11  1987-06-28  FI_ACCOUNT    7700             NaN       108.0          100.0
# 9   1987-06-26  FI_ACCOUNT    9000             NaN       108.0          100.0
# 12  1987-06-29  FI_ACCOUNT    7800             NaN       108.0          100.0
# 1   1987-06-18       AD_VP   17000             NaN       100.0           90.0
# 52  1987-08-08      SA_REP    9000            0.25       145.0           80.0
# 68  1987-08-24      SA_REP   11500            0.25       148.0           80.0
# 75  1987-08-31      SA_REP    8800            0.25       149.0           80.0
# 53  1987-08-09      SA_REP    8000            0.20       145.0           80.0
# 55  1987-08-11      SA_REP    7000            0.15       145.0           80.0
# 50  1987-08-06      SA_REP   10000            0.30       145.0           80.0

# %% [markdown]
# # Ejercicio 197
#
# Obtener los empleados que pertenezcan ya sea a los departamentos con ID 80 ó 30.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[df['department_id'].isin([80, 30])]

# %%
len(df)
# Out:
# 107

# %%
len(resultado)
# Out:
# 40

# %%
for index, f in resultado.iterrows():
    print(f['first_name'].ljust(15), f['last_name'].ljust(15), f['department_id'])
# Out:
# Den             Raphaely        30.0
# Alexander       Khoo            30.0
# Shelli          Baida           30.0
# Sigal           Tobias          30.0
# Guy             Himuro          30.0
# Karen           Colmenares      30.0
# John            Russell         80.0
# Karen           Partners        80.0
# Alberto         Errazuriz       80.0
# Gerald          Cambrault       80.0
# Eleni           Zlotkey         80.0
# Peter           Tucker          80.0
# David           Bernstein       80.0
# Peter           Hall            80.0
# Christopher     Olsen           80.0
# Nanette         Cambrault       80.0
# Oliver          Tuvault         80.0
# Janette         King            80.0
# Patrick         Sully           80.0
# Allan           McEwen          80.0
# Lindsey         Smith           80.0
# Louise          Doran           80.0
# Sarath          Sewall          80.0
# Clara           Vishney         80.0
# Danielle        Greene          80.0
# Mattea          Marvins         80.0
# David           Lee             80.0
# Sundar          Ande            80.0
# Amit            Banda           80.0
# Lisa            Ozer            80.0
# Harrison        Bloom           80.0
# Tayler          Fox             80.0
# William         Smith           80.0
# Elizabeth       Bates           80.0
# Sundita         Kumar           80.0
# Ellen           Abel            80.0
# Alyssa          Hutton          80.0
# Jonathon        Taylor          80.0
# Jack            Livingston      80.0
# Charles         Johnson         80.0

# %% [markdown]
# # Ejercicio 198
#
# Obtener empleados cuyo jefe tenga como ID 100, 124, o 149.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[df['manager_id'].isin([100, 124, 149])]

resultado.head(10)
# Out:
#     employ_id first_name last_name     email  phone_number   hire_date  \
# 1         101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2         102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 14        114        Den  Raphaely  DRAPHEAL  515.127.4561  1987-07-01
# 20        120    Matthew     Weiss    MWEISS  650.123.1234  1987-07-07
# 21        121       Adam     Fripp    AFRIPP  650.123.2234  1987-07-08
# 22        122      Payam  Kaufling  PKAUFLIN  650.123.3234  1987-07-09
# 23        123     Shanta   Vollman  SVOLLMAN  650.123.4234  1987-07-10
# 24        124      Kevin   Mourgos  KMOURGOS  650.123.5234  1987-07-11
# 41        141     Trenna      Rajs     TRAJS  650.121.8009  1987-07-28
# 42        142     Curtis    Davies   CDAVIES  650.121.2994  1987-07-29
#
#       job_id  salary  commission_pct  manager_id  department_id
# 1      AD_VP   17000             NaN       100.0           90.0
# 2      AD_VP   17000             NaN       100.0           90.0
# 14    PU_MAN   11000             NaN       100.0           30.0
# 20    ST_MAN    8000             NaN       100.0           50.0
# 21    ST_MAN    8200             NaN       100.0           50.0
# 22    ST_MAN    7900             NaN       100.0           50.0
# 23    ST_MAN    6500             NaN       100.0           50.0
# 24    ST_MAN    5800             NaN       100.0           50.0
# 41  ST_CLERK    3500             NaN       124.0           50.0
# 42  ST_CLERK    3100             NaN       124.0           50.0

# %%
for i, f in resultado.iterrows():
    print(f['first_name'].ljust(15), f['last_name'].ljust(15), f['manager_id'])
# Out:
# Steven          King            nan
# Neena           Kochhar         100.0
# Lex             De Haan         100.0
# Alexander       Hunold          102.0
# Bruce           Ernst           103.0
# David           Austin          103.0
# Valli           Pataballa       103.0
# Diana           Lorentz         103.0
# Nancy           Greenberg       101.0
# Daniel          Faviet          108.0
# John            Chen            108.0
# Ismael          Sciarra         108.0
# Jose Manuel     Urman           108.0
# Luis            Popp            108.0
# Matthew         Weiss           100.0
# Adam            Fripp           100.0
# Payam           Kaufling        100.0
# Shanta          Vollman         100.0
# Kevin           Mourgos         100.0
# Julia           Nayer           120.0
# Irene           Mikkilineni     120.0
# James           Landry          120.0
# Steven          Markle          120.0
# Laura           Bissot          121.0
# Mozhe           Atkinson        121.0
# James           Marlow          121.0
# TJ              Olson           121.0
# Jason           Mallin          122.0
# Michael         Rogers          122.0
# Ki              Gee             122.0
# Hazel           Philtanker      122.0
# Renske          Ladwig          123.0
# Stephen         Stiles          123.0
# John            Seo             123.0
# Joshua          Patel           123.0
# Trenna          Rajs            124.0
# Curtis          Davies          124.0
# Randall         Matos           124.0
# Peter           Vargas          124.0
# Kimberely       Grant           149.0
# Winston         Taylor          120.0
# Jean            Fleaur          120.0
# Martha          Sullivan        120.0
# Girard          Geoni           120.0
# Nandita         Sarchand        121.0
# Alexis          Bull            121.0
# Julia           Dellinger       121.0
# Anthony         Cabrio          121.0
# Kelly           Chung           122.0
# Jennifer        Dilly           122.0
# Timothy         Gates           122.0
# Randall         Perkins         122.0
# Sarah           Bell            123.0
# Britney         Everett         123.0
# Samuel          McCain          123.0
# Vance           Jones           123.0
# Alana           Walsh           124.0
# Kevin           Feeney          124.0
# Donald          OConnell        124.0
# Douglas         Grant           124.0
# Jennifer        Whalen          101.0
# Michael         Hartstein       100.0
# Pat             Fay             201.0
# Susan           Mavris          101.0
# Hermann         Baer            101.0
# Shelley         Higgins         101.0
# William         Gietz           205.0

# %% [markdown]
# # Ejercicio 199
#
# Encontrar aquellos empleados que en su nombre la tercera letra es una _r_.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[df['first_name'].str[2:3] == 'r']

resultado
# Out:
#      employ_id   first_name   last_name     email        phone_number  \
# 19         119        Karen  Colmenares  KCOLMENA        515.127.4566
# 42         142       Curtis      Davies   CDAVIES        650.121.2994
# 46         146        Karen    Partners  KPARTNER  011.44.1344.467268
# 48         148       Gerald   Cambrault  GCAMBRAU  011.44.1344.619268
# 53         153  Christopher       Olsen    COLSEN  011.44.1344.498718
# 61         161       Sarath      Sewall   SSEWALL  011.44.1345.529268
# 69         169     Harrison       Bloom    HBLOOM  011.44.1343.829268
# 82         182       Martha    Sullivan  MSULLIVA        650.507.9878
# 83         183       Girard       Geoni    GGEONI        650.507.9879
# 92         192        Sarah        Bell     SBELL        650.501.1876
# 104        204      Hermann        Baer     HBAER        515.123.8888
#
#       hire_date    job_id  salary  commission_pct  manager_id  department_id
# 19   1987-07-06  PU_CLERK    2500             NaN       114.0           30.0
# 42   1987-07-29  ST_CLERK    3100             NaN       124.0           50.0
# 46   1987-08-02    SA_MAN   13500            0.30       100.0           80.0
# 48   1987-08-04    SA_MAN   11000            0.30       100.0           80.0
# 53   1987-08-09    SA_REP    8000            0.20       145.0           80.0
# 61   1987-08-17    SA_REP    7000            0.25       146.0           80.0
# 69   1987-08-25    SA_REP   10000            0.20       148.0           80.0
# 82   1987-09-07  SH_CLERK    2500             NaN       120.0           50.0
# 83   1987-09-08  SH_CLERK    2800             NaN       120.0           50.0
# 92   1987-09-17  SH_CLERK    4000             NaN       123.0           50.0
# 104  1987-09-29    PR_REP   10000             NaN       101.0           70.0

# %%
for i, f in resultado.iterrows():
    print(f['first_name'].ljust(15), f['phone_number'].ljust(15))
# Out:
# Steven          515.123.4567
# Neena           515.123.4568
# Lex             515.123.4569
# Alexander       590.423.4567
# Bruce           590.423.4568
# David           590.423.4569
# Valli           590.423.4560
# Diana           590.423.5567
# Nancy           515.124.4569
# Daniel          515.124.4169
# John            515.124.4269
# Ismael          515.124.4369
# Jose Manuel     515.124.4469
# Luis            515.124.4567
# Matthew         650.123.1234
# Adam            650.123.2234
# Payam           650.123.3234
# Shanta          650.123.4234
# Kevin           650.123.5234
# Julia           650.124.1214
# Irene           650.124.1224
# James           650.124.1334
# Steven          650.124.1434
# Laura           650.124.5234
# Mozhe           650.124.6234
# James           650.124.7234
# TJ              650.124.8234
# Jason           650.127.1934
# Michael         650.127.1834
# Ki              650.127.1734
# Hazel           650.127.1634
# Renske          650.121.1234
# Stephen         650.121.2034
# John            650.121.2019
# Joshua          650.121.1834
# Trenna          650.121.8009
# Curtis          650.121.2994
# Randall         650.121.2874
# Peter           650.121.2004
# Kimberely       011.44.1644.429263
# Winston         650.507.9876
# Jean            650.507.9877
# Martha          650.507.9878
# Girard          650.507.9879
# Nandita         650.509.1876
# Alexis          650.509.2876
# Julia           650.509.3876
# Anthony         650.509.4876
# Kelly           650.505.1876
# Jennifer        650.505.2876
# Timothy         650.505.3876
# Randall         650.505.4876
# Sarah           650.501.1876
# Britney         650.501.2876
# Samuel          650.501.3876
# Vance           650.501.4876
# Alana           650.507.9811
# Kevin           650.507.9822
# Donald          650.507.9833
# Douglas         650.507.9844
# Jennifer        515.123.4444
# Michael         515.123.5555
# Pat             603.123.6666
# Susan           515.123.7777
# Hermann         515.123.8888
# Shelley         515.123.8080
# William         515.123.8181

# %%
resultado.info
# Out:
# <bound method DataFrame.info of      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  1987-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104      Bruce     Ernst    BERNST  590.423.4568  1987-06-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  1987-09-27
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  1987-09-28
# 104        204    Hermann      Baer     HBAER  515.123.8888  1987-09-29
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206    William     Gietz    WGIETZ  515.123.8181  1987-10-01
#
#          job_id  salary  commission_pct  manager_id  department_id
# 0       AD_PRES   24000             NaN         NaN           90.0
# 1         AD_VP   17000             NaN       100.0           90.0
# 2         AD_VP   17000             NaN       100.0           90.0
# 3       IT_PROG    9000             NaN       102.0           60.0
# 4       IT_PROG    6000             NaN       103.0           60.0
# ..          ...     ...             ...         ...            ...
# 102      MK_REP    6000             NaN       201.0           20.0
# 103      HR_REP    6500             NaN       101.0           40.0
# 104      PR_REP   10000             NaN       101.0           70.0
# 105      AC_MGR   12000             NaN       101.0          110.0
# 106  AC_ACCOUNT    8300             NaN       205.0          110.0
#
# [67 rows x 11 columns]>

# %% [markdown]
# # Ejercicio 200
#
# Obtener los empleados que **no** pertenezcan a los departamentos con ID 80 ó 30.
#
# ## Solución:

# %%
import pandas as pd

# %%
nombre_archivo = 'employees.csv'

df = pd.read_csv(nombre_archivo)

# %%
df.head(7)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
#
#     job_id  salary  commission_pct  manager_id  department_id
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0
# 5  IT_PROG    4800             NaN       103.0           60.0
# 6  IT_PROG    4800             NaN       103.0           60.0

# %%
resultado = df[~df['department_id'].isin([30, 80])]

resultado.head(10)
# Out:
#    employ_id first_name  last_name     email  phone_number   hire_date  \
# 0        100     Steven       King     SKING  515.123.4567  1987-06-17
# 1        101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2        102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3        103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4        104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5        105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6        106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7        107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8        108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9        109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id
# 0     AD_PRES   24000             NaN         NaN           90.0
# 1       AD_VP   17000             NaN       100.0           90.0
# 2       AD_VP   17000             NaN       100.0           90.0
# 3     IT_PROG    9000             NaN       102.0           60.0
# 4     IT_PROG    6000             NaN       103.0           60.0
# 5     IT_PROG    4800             NaN       103.0           60.0
# 6     IT_PROG    4800             NaN       103.0           60.0
# 7     IT_PROG    4200             NaN       103.0           60.0
# 8      FI_MGR   12000             NaN       101.0          100.0
# 9  FI_ACCOUNT    9000             NaN       108.0          100.0

# %%
resultado
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  1987-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104      Bruce     Ernst    BERNST  590.423.4568  1987-06-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  1987-09-27
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  1987-09-28
# 104        204    Hermann      Baer     HBAER  515.123.8888  1987-09-29
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206    William     Gietz    WGIETZ  515.123.8181  1987-10-01
#
#          job_id  salary  commission_pct  manager_id  department_id
# 0       AD_PRES   24000             NaN         NaN           90.0
# 1         AD_VP   17000             NaN       100.0           90.0
# 2         AD_VP   17000             NaN       100.0           90.0
# 3       IT_PROG    9000             NaN       102.0           60.0
# 4       IT_PROG    6000             NaN       103.0           60.0
# ..          ...     ...             ...         ...            ...
# 102      MK_REP    6000             NaN       201.0           20.0
# 103      HR_REP    6500             NaN       101.0           40.0
# 104      PR_REP   10000             NaN       101.0           70.0
# 105      AC_MGR   12000             NaN       101.0          110.0
# 106  AC_ACCOUNT    8300             NaN       205.0          110.0
#
# [67 rows x 11 columns]
